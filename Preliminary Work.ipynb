# %% [markdown]
# ### Step 0. Downloading the data
#
# Data are downloaded from https://www.kaggle.com/code/naubergois/training-of-eeg-schizophrenia-disorder-using-cnn
#
#
# ### Step 1. Looking at the data

# %%
import pandas as pd

# %%
df1 = pd.read_csv("../archive/1.csv/1.csv")

# %%
df1.head()
# Out:
#    1.0000  100.0000  1.0000.1  1.0000.2  -8.0053  -13.0829  -20.5564  4.2336
# 0     1.0     100.0       1.0       2.0  -8.8933  -14.1654  -21.8203  3.3877  \
# 1     1.0     100.0       1.0       3.0  -8.9066  -16.4452  -22.7497  3.4377
# 2     1.0     100.0       1.0       4.0  -9.7299  -19.1422  -25.0143  1.5351
# 3     1.0     100.0       1.0       5.0 -11.2229  -20.6806  -27.1648 -1.9990
# 4     1.0     100.0       1.0       6.0 -12.9256  -21.6013  -29.3992 -4.1841
#
#    -8.7248  0.8437  ...  -10.3872  -2.8699  -3.0858  5.1531  22.0115   9.5887
# 0  -9.7117  1.7590  ...   -7.8821  -1.7557  -3.6627  5.4636  22.5037  10.3699  \
# 1  -9.2680  1.9539  ...   -6.6525  -1.1273  -3.8116  6.4276  23.1991  10.5730
# 2 -11.2621 -0.2113  ...   -9.4611  -3.8643  -4.6691  4.8833  22.8632   8.4012
# 3 -14.7915 -3.2781  ...  -12.8175  -7.7093  -6.7313  0.2697  20.3886   3.6517
# 4 -16.5108 -5.9829  ...  -14.3862  -9.7969  -8.2848 -2.8699  16.3808   0.1517
#
# ...

# %%
# !ls ../archive
# Out:
# 1.csv               20.csv              69.csv              8.csv
# 10.csv              21.csv              7.csv               80.csv
# 11.csv              22.csv              70.csv              81.csv
# 12.csv              23.csv              71.csv              9.csv
# 13.csv              24.csv              72.csv              ERPdata.csv
# 14.csv              3.csv               73.csv              columnLabels.csv
# 15.csv              4.csv               74.csv              demographic.csv
# 16.csv              5.csv               75.csv              mergedTrialData.csv
# 17.csv              6.csv               76.csv              time.csv
# 18.csv              66.csv              77.csv
# 19.csv              67.csv              78.csv
# 2.csv               68.csv              79.csv

# %%
ls
